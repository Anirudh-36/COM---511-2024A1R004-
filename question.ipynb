# %%
# 1. Write a python program to perform addistion,subtraction,multiplication,division of two numbers.Also find quotient.
a = 4
b = 2
print("Addition :",a+b)
print("Subtraction :",a-b)
print("Multiplication : ",a*b)
print("Division : ",a%b)
print("Quotient : ",a//b)
# Out:
# Addition : 6
# Subtraction : 2
# multiplication :  8
# Division :  0
# Quotient :  2

# %%
# 2. Write a python program to find remainder when a remainder when a number is divided by z.
a = int(input("Enter a number: "))
z = int(input("Enter the divisor: "))
remainder = a % z
print("Remainder =", remainder)
# Out:
# Remainder = 0

# %%
# 3. Check the type of variable assigned using input() function.
print(type(input()))
# Out:
# <class 'str'>

# %%
# 4. use comparison operator to find out whether 'a' given variable is greater than 'b' or not.Take a = 34 and b = 80
a = int(input("Enter 1 number : "))
b = int(input("Enter 2 number : "))
if a > b:
    print("A is greater ")
else:
    print("B is greater ")
# Out:
# B is greater

# %%
# 5. Write a python to find an average of two numbers entered by the user.
a = int(input("Enter first number : "))
b = int(input("Enter second number : "))
average = (a + b) // 2
print("Average : ",average)
# Out:
# Average :  3

# %%
# 6. Write a python program to calculate the square of a number entered by the user.
a = int(input("Enter a number : "))
square = a * a
print("Square : ",square)
# Out:
# Square :  16

# %%
# 7. Write a program to take temperature in Celsius from the user and convert it into Fahrenheit
celsius = float(input("Enter temperature in Celsius: "))
fahrenheit = (celsius * 9/5) + 32
print("Temperature in Fahrenheit =", fahrenheit)
# Out:
# Temperature in Fahrenheit = 80.6

# %%
# 8. Write a python program to calculate simple Interest and total amount using Principal,Rate, and Time entered by the user. 
P = float(input("Enter Principal : "))
R = float(input("Enter Rate : "))
T = float(input("Enter Time : "))

SI = (P * R * T) / 100
Amount = P + SI

print("Simple Interest =", SI)
print("Total Amount =", Amount)
# Out:
# Simple Interest = 1.2
# Total Amount = 5.2

# %%
# 9. Write a Python program to take distance in Kilometers and convert it into meters,centimeters, and millimeters.
km = float(input("Enter distance in Kilometers: "))
meters = km * 1000
centimeters = km * 100000
millimeters = km * 1000000

print("Meters =", meters)
print("Centimeters =", centimeters)
print("Millimeters =", millimeters)
# Out:
# Meters = 5000.0
# Centimeters = 500000.0
# Millimeters = 5000000.0

# %%
# 10. Write a Python program to ask the user for radius and calculate area and circumference of circle.
radius = float(input("Enter Radius :"))
area = 3.14 * radius * radius
circumference = 2 * 3.14 * radius
print("Area = ",area)
print(f"Circumference :{circumference:.2f}")
# Out:
# Area =  78.5
# Circumference : 31.40

# %%
# 11. Write a Python Program to take a base number x and an exponent y as input and calculate x raised to the power y.
x = int(input("Enter base number x: "))
y = int(input("Enter exponent y: "))
print("Result =", x ** y)
# Out:
# Result = 4

# %%
# 12. Write a Python program to take total minutes as input and convert it into hours and remaining minutes.
minutes = int(input("Enter total minutes: "))
hours = minutes // 60
remaining_minutes = minutes % 60
print("Hours =", hours)
print("Remaining minutes =", remaining_minutes)
# Out:
# Hours = 0
# Remaining minutes = 25

# %%
# 13. Write a Python program to take a 2-digit numbers as input and print the sum of its digits.
num = int(input("Enter number : "))
a = num //10
b = num % 10
sum = a + b
print("Sum = ",sum)
# Out:
# Sum =  12

# %%
# 14. Program to calculate the number of ₹500 and ₹100 notes required

amount = int(input("Enter amount in rupees: "))

notes_500 = amount // 500
remaining = amount % 500

notes_100 = remaining // 100

print("Number of ₹500 notes:", notes_500)
print("Number of ₹100 notes:", notes_100)
# Out:
# Number of ₹500 notes: 10
# Number of ₹100 notes: 0

# %%
# 15. Write a Python program to take two inputs a and b, swap their values using a temporary variable, and print updated values.
a = int(input("Enter 1 number :"))
b = int(input("Enter 2 number : "))
temp = a
a = b
b = temp
print("a = ",a)
print("b = ",b)
# Out:
# a =  5
# b =  2

# %%
# 16. Write a Python program to swap two numbers without using a third variable.(Use arithmetic Operators)
a = int(input("Enter 1 number :"))
b = int(input("Enter 2 number :"))

a = a + b
b = a - b
a = a - b

print("a =", a)
print("b =", b)
# Out:
# a = 5
# b = 2

# %%
# 17. Initialie a variable balance = 1000. Perform operations using shorthand operators like +=,-=,*=,/= and print the updated balance after each operation.

# balance = 1000
# balance += 500
# print("After += :", balance)
# balance -= 200
# print("After -= :",balance)
# balance *= 2
# print("After *= :",balance)
# balance /= 2
# print("After /= :",balance)

balance = int(input("Enter Balance: "))

add = int(input("Enter amount to add: "))
balance += add
print("After += :", balance)

subtract = int(input("Enter amount to subtract: "))
balance -= subtract
print("After -= :", balance)

multiply = int(input("Enter number to multiply: "))
balance *= multiply
print("After *= :", balance)

divide = int(input("Enter number to divide: "))
balance /= divide
print("After /= :", balance)
# Out:
# After += : 1500
# After -= : 1300
# After *= : 2600
# After /= : 1300.0

# %%
# 18. Write a Python program to take age as input and print True if age is between 18 and 60, otherwise print False.
age = int(input("Enter Age :"))
if age >= 18 and age <= 60:
    print("True")
else:
    print("False")
# Out:
# True

# %%
# 19. Write a Python program to take marks of three subjects out of 100. Print True if the student scored at least 40 in all three subjects and average marks at least 50. 
a = int(input("Enter marks of subject 1: "))
b = int(input("Enter marks of subject 2: "))
c = int(input("Enter marks of subject 3: "))

if a and b and c>= 40 and (a+b+c)/3 >= 50:
    print("True")
else:
    print("False")
# Out:
# True

# %%
# 20. Write a Python program to take an integor and print True if the number is even and False if the number is odd.
integor = int(input("Enter number : "))
if integor % 2 == 0:
    print("True")
else:
    print("False")
# Out:
# True

# %%
# 21. write a Python program to take input from the user without typecasting and multiply it by 3. Then typecast the same input to int and multiply it by 3. Print both results to show thw difference.

user = (input("Enter input :"))

result1 = user * 3
print("Without typecasting:", result1)

user = int(user)

result2 = user * 3
print("After typecasting:", result2)
# Out:
# Without typecasting: 222
# After typecasting: 6

# %%
# 22. Write a Python program to take student details like name, roll number, CGPA, and hostel status from the user. Typecast the roll number to int, CGPA to float, and hostel status to bool, then print all the details.
name = input("Enter name :")
roll_no = int(input("Enter roll number :"))
cgpa = float(input("Enter CGPA :"))
is_hosteller = bool(input("Are you a hosteller? "))

print("Name :",name,type(name))
print("Roll Number :",roll_no,type(roll_no))
print("CGPA :",cgpa,type(cgpa))
print("Hosteller : ",is_hosteller,type(is_hosteller))
# Out:
# Name : anirudh <class 'str'>
# Roll Number : 4 <class 'int'>
# CGPA : 9.0 <class 'float'>
# Hosteller :  True <class 'bool'>
