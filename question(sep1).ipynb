# %%
# 1. Write a Python program to display a user - entered name followed by "Good Afternoon" using input() function(Use f-string)
name = input("Enter Name :")
print(f"Good Afternoon",{name})
# Out:
# Good Afternoon {'anirudh'}

# %%
# 2. Write a Python program to fill the given letter template with name and date.
# letter = '''
# Dear <Name>,
# You are selected! 
# <Date>
name = input("Enter name: ")
date =input("Enter Date: ")

print(f"Dear {name},\nYou are selected!\n{date}\nThank you")
# Out:
# Dear Anirudh,
# You are selected
# 1 sep
# Thank you

# %%
# 3. Write a Python program to detect double space in a string.
string = input("Enter a string :")
# print("  " in string) # return True if double space otherwise false.
print(string.find("  ")) # returns the last index number where double space starts.
# Out:
# 3

# %%
# 4. Write a Python program to replace double spaces from problem 3 with single spaces.
string = input("Enter a string: ")
string = string.replace("  ", " ")
print(string)
# Out:
# Anirudh hello python

# %%
# 5. Write a Python program to format the following letter using escape sequence characters.
# letter = "Dear Saurabh, this python course is nice. Thanks!"
letter = "Dear Saurabh,\n\tThis Python course is nice.\nThanks!"
print(letter)
# Out:
# Dear Saurabh,
# 	This Python course is nice.
# Thanks!

# %%
# 6. Writen a Python program to take a student's full name and display :
# 1. Total Number of characters
# 2. First character
# 3. Last character
# 4. Name uin uppercase form
name = input("Enter Full Name :")
print("Total characters:", len(name))
print("First character:", name[0])
print("Last character:", name[-1])
print("Uppercase:", name.upper())
# Out:
# Total characters: 7
# First character: a
# Last character: h
# Uppercase: ANIRUDH

# %%
# 7. Write a Python program to take a student name and roll number,then generate a username using the first 3 letters of the name and last 2 digits of the roll number.
name = input("Enter Name: ")
roll_no = input("Enter Roll No: ")

username = name[:3] + roll_no[-2:]
print("Username:", username)
# Out:
# Username: ani04

# %%
# 8. Write a Python Program to tale an email address and print the domain name.
Email = input("Enter Email Address :")
domain = Email.split("@")[1]
print("Domain:", domain)
# Out:
# Domain: mietjammu.in

# %%
# 9. Write a Python program to check whether an email ends with mietjammu.in
email = input("Enter Email Address: ")
print(email.endswith("mietjammu.in"))
# Out:
# True

# %%
# 10. Write a Python program to take 10-digit mobile number and display only the last 4 digits.Replace the first 6 digitds with ******.
Mobile_no = input("Enter Mobile No: ")
print("Mobile Number:", "******" + Mobile_no[-4:])
# Out:
# Mobile Number: ******7331
